# %% [markdown]
# <a href="https://colab.research.google.com/github/adrian-ai-salud/adrian-ai-salud/blob/main/Ejercicio1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EJERCICIO 1
#
# ## CARGA DE LA BASE DE DATOS

# %%
# !pip install pingouin
# !pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.4/204.4 kB 3.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Cargar el archivo "ejercicio1.xlsx" y ejecutar.
# ## Ejecutar e id al final para cargar el archivo y ver la propuesta

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import warnings
warnings.filterwarnings('ignore')

# Configuración de visualización
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12

# Establecer una paleta de colores pastel
colores_pastel = ['#A8D8EA', '#AA96DA', '#FCBAD3', '#FFFFD2', '#B5EAD7', '#FF9AA2', '#C7CEEA', '#E2F0CB']
sns.set_palette(sns.color_palette(colores_pastel))

# 1. Carga de datos
def cargar_datos():
    """
    Carga los datos desde un archivo Excel usando Google Colab.
    Permite al usuario subir el archivo de forma interactiva.
    """
    try:
        # Importar google.colab para subir archivos
        from google.colab import files
        import io

        print("Por favor, sube el archivo Excel con los datos del estudio.")
        print("Haz clic en el botón 'Elegir archivos' que aparecerá.")

        # Subir archivo
        archivos_subidos = files.upload()

        # Obtener el nombre del primer archivo subido
        nombre_archivo = list(archivos_subidos.keys())[0]
        print(f"Archivo subido: {nombre_archivo}")

        # Leer el contenido del archivo
        contenido = archivos_subidos[nombre_archivo]

        # Convertir a DataFrame
        df = pd.read_excel(io.BytesIO(contenido))
        print(f"Datos cargados: {df.shape[0]} filas y {df.shape[1]} columnas")

        return df

    except ImportError:
        # Alternativa si no estamos en Colab
        print("No se detectó Google Colab. Se usará la carga estándar de archivos.")

        # Solicitar ruta del archivo
        ruta_archivo = input("Introduce la ruta del archivo Excel: ")
        df = pd.read_excel(ruta_archivo)
        print(f"Datos cargados: {df.shape[0]} filas y {df.shape[1]} columnas")

        return df

# 2. Análisis descriptivo
def analisis_descriptivo(df):
    """
    Realiza un análisis descriptivo de los datos con gráficos.
    """
    print("\n--- ANÁLISIS DESCRIPTIVO ---")

    # Resumen estadístico general
    print("\nResumen estadístico general:")
    print(df.describe().round(2))

    # Distribución de variables categóricas
    plt.figure(figsize=(16, 6))

    # Distribución por sexo
    plt.subplot(1, 3, 1)
    sns.countplot(x='Sexo', data=df)
    plt.title('Distribución por Sexo')
    plt.ylabel('Frecuencia')

    # Distribución por tratamiento
    plt.subplot(1, 3, 2)
    ax = sns.countplot(x='Tratamiento', data=df)
    plt.title('Distribución por Tratamiento')
    plt.ylabel('Frecuencia')
    for p in ax.patches:
        ax.annotate(f'{int(p.get_height())}',
                    (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha = 'center', va = 'bottom')

    # Histograma de edades
    plt.subplot(1, 3, 3)
    sns.histplot(df['Edad'], kde=True, bins=10)
    plt.title('Distribución de Edades')
    plt.xlabel('Edad')
    plt.ylabel('Frecuencia')

    plt.tight_layout()
    plt.savefig('distribucion_demografica.png')
    plt.show()  # Añadido para mostrar el gráfico en Colab

    # Visualización de las variables principales
    plt.figure(figsize=(16, 6))

    # Histogramas de colesterol inicial y final
    plt.subplot(1, 2, 1)
    sns.histplot(df['Colesterol_Inicial'], kde=True, color='blue')
    plt.title('Distribución Colesterol Inicial')
    plt.xlabel('Colesterol Inicial')

    plt.subplot(1, 2, 2)
    sns.histplot(df['Colesterol_Final'], kde=True, color='green')
    plt.title('Distribución Colesterol Final')
    plt.xlabel('Colesterol Final')

    plt.tight_layout()
    plt.savefig('distribucion_colesterol.png')
    plt.show()  # Añadido para mostrar el gráfico en Colab

    # Scatterplot Colesterol Inicial vs Final por tratamiento
    plt.figure(figsize=(10, 8))
    sns.scatterplot(x='Colesterol_Inicial', y='Colesterol_Final',
                    hue='Tratamiento', data=df, s=100, alpha=0.7)
    plt.title('Colesterol Inicial vs Final por Tratamiento')
    plt.xlabel('Colesterol Inicial')
    plt.ylabel('Colesterol Final')
    # Línea de referencia (sin cambio)
    x = np.linspace(df['Colesterol_Inicial'].min(), df['Colesterol_Inicial'].max(), 100)
    plt.plot(x, x, 'k--', alpha=0.5, label='Sin cambio')
    plt.legend(title='Tratamiento')
    plt.savefig('scatter_colesterol.png')
    plt.show()  # Añadido para mostrar el gráfico en Colab

# 3. Análisis univariante
def analisis_univariante(df):
    """
    Realiza análisis univariante de las variables principales.
    """
    print("\n--- ANÁLISIS UNIVARIANTE ---")

    variables = ['Edad', 'Colesterol_Inicial', 'Colesterol_Final']

    for var in variables:
        stats_univar = df[var].describe()
        skewness = df[var].skew()
        kurtosis = df[var].kurtosis()

        print(f"\nEstadísticos univariantes para {var}:")
        print(f"Media: {stats_univar['mean']:.2f}")
        print(f"Desviación estándar: {stats_univar['std']:.2f}")
        print(f"Mínimo: {stats_univar['min']:.2f}")
        print(f"Q1 (25%): {stats_univar['25%']:.2f}")
        print(f"Mediana: {stats_univar['50%']:.2f}")
        print(f"Q3 (75%): {stats_univar['75%']:.2f}")
        print(f"Máximo: {stats_univar['max']:.2f}")
        print(f"Asimetría (Skewness): {skewness:.3f}")
        print(f"Curtosis: {kurtosis:.3f}")

        # Interpretación de la asimetría y curtosis
        if abs(skewness) < 0.5:
            print("La distribución es aproximadamente simétrica.")
        elif skewness < 0:
            print("La distribución tiene asimetría negativa (cola hacia la izquierda).")
        else:
            print("La distribución tiene asimetría positiva (cola hacia la derecha).")

        if abs(kurtosis) < 0.5:
            print("La distribución tiene curtosis similar a la normal.")
        elif kurtosis < 0:
            print("La distribución es platicúrtica (más plana que la normal).")
        else:
            print("La distribución es leptocúrtica (más puntiaguda que la normal).")

# 4. Análisis de normalidad
def analisis_normalidad(df):
    """
    Evalúa la normalidad de las variables en los tres grupos de tratamiento
    mediante pruebas estadísticas y gráficos Q-Q.
    """
    print("\n--- ANÁLISIS DE NORMALIDAD ---")

    # Variables a evaluar
    variables = ['Colesterol_Inicial', 'Colesterol_Final']

    # Pruebas de normalidad por grupo de tratamiento
    for var in variables:
        print(f"\nPruebas de normalidad para {var} por grupo de tratamiento:")

        # Enfoque más simple y confiable para gráficos Q-Q (separados)
        grupos = df.groupby('Tratamiento')
        for nombre_tratamiento, grupo in grupos:
            # Prueba de Shapiro-Wilk
            shapiro_test = stats.shapiro(grupo[var])
            print(f"Tratamiento {nombre_tratamiento} - Shapiro-Wilk: estadístico={shapiro_test.statistic:.4f}, p-valor={shapiro_test.pvalue:.4f}")

            if shapiro_test.pvalue > 0.05:
                resultado = f"✓ Normal (p={shapiro_test.pvalue:.4f})"
                print(f"  ✓ La distribución para el tratamiento {nombre_tratamiento} parece ser normal (p > 0.05)")
            else:
                resultado = f"✗ No normal (p={shapiro_test.pvalue:.4f})"
                print(f"  ✗ La distribución para el tratamiento {nombre_tratamiento} no parece ser normal (p ≤ 0.05)")

            # Crear figura con gráfico Q-Q e histograma lado a lado
            fig, (ax_qq, ax_hist) = plt.subplots(1, 2, figsize=(14, 6))

            # Gráfico Q-Q
            sm.qqplot(grupo[var], line='s', ax=ax_qq)
            ax_qq.set_title(f'Gráfico Q-Q para Tratamiento {nombre_tratamiento}\n{resultado}')
            ax_qq.grid(True, linestyle='--', alpha=0.7)
            ax_qq.set_xlabel('Cuantiles teóricos')
            ax_qq.set_ylabel('Cuantiles observados')

            # Histograma con curva normal
            color = {'A': '#A8D8EA', 'B': '#FCBAD3', 'C': '#B5EAD7'}[nombre_tratamiento]
            sns.histplot(grupo[var], kde=True, color=color, ax=ax_hist, alpha=0.7, edgecolor='white')

            # Superponer curva normal teórica
            x = np.linspace(grupo[var].min(), grupo[var].max(), 100)
            y = stats.norm.pdf(x, grupo[var].mean(), grupo[var].std())
            y = y * (len(grupo[var]) * np.diff(ax_hist.get_xlim())[0] / 10)  # Escalar la curva
            ax_hist.plot(x, y, 'r-', linewidth=2)

            ax_hist.set_title(f'Histograma para Tratamiento {nombre_tratamiento}')
            ax_hist.set_xlabel(var)
            ax_hist.set_ylabel('Frecuencia')

            # Añadir texto con estadísticos descriptivos
            stats_text = f"Media: {grupo[var].mean():.2f}\nDE: {grupo[var].std():.2f}\nN: {len(grupo)}"
            ax_hist.text(0.95, 0.95, stats_text, transform=ax_hist.transAxes,
                      verticalalignment='top', horizontalalignment='right',
                      bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

            plt.tight_layout()
            plt.savefig(f'normalidad_{var}_{nombre_tratamiento}.png')
            plt.show()  # Mostrar el gráfico en Colab

        # Normalidad general (combinando todos los grupos)
        print(f"\nPrueba de normalidad general para {var} (todos los grupos):")
        shapiro_general = stats.shapiro(df[var])
        print(f"Shapiro-Wilk: estadístico={shapiro_general.statistic:.4f}, p-valor={shapiro_general.pvalue:.4f}")

        if shapiro_general.pvalue > 0.05:
            resultado_general = f"✓ Normal (p={shapiro_general.pvalue:.4f})"
            print(f"  ✓ La distribución general de {var} parece ser normal (p > 0.05)")
        else:
            resultado_general = f"✗ No normal (p={shapiro_general.pvalue:.4f})"
            print(f"  ✗ La distribución general de {var} no parece ser normal (p ≤ 0.05)")
            print("    Nota: Para ANOVA, la normalidad de los residuos es más importante que la de los datos brutos.")

        # Gráfico Q-Q general
        plt.figure(figsize=(10, 6))
        sm.qqplot(df[var], line='s')
        plt.title(f'Gráfico Q-Q General para {var}\n{resultado_general}')
        plt.grid(True, linestyle='--', alpha=0.7)
        plt.tight_layout()
        plt.savefig(f'normalidad_{var}_general.png')
        plt.show()  # Mostrar el gráfico en Colab

# 5. Análisis con Boxplots
def analisis_boxplot(df):
    """
    Crea y analiza diagramas de caja para visualizar la distribución por grupos.
    """
    print("\n--- ANÁLISIS DE BOXPLOTS ---")

    # Paleta de colores pastel
    paleta = sns.color_palette("pastel")

    # Boxplots para Colesterol Inicial y Final por tratamiento
    fig, axes = plt.subplots(1, 2, figsize=(16, 7))

    # Boxplot para Colesterol Inicial
    sns.boxplot(x='Tratamiento', y='Colesterol_Inicial', data=df, ax=axes[0], palette=paleta)
    sns.stripplot(x='Tratamiento', y='Colesterol_Inicial', data=df, ax=axes[0],
                 color='black', alpha=0.5, jitter=True, size=4)

    axes[0].set_title('Colesterol Inicial por Tratamiento', fontsize=14)
    axes[0].set_ylabel('Colesterol Inicial', fontsize=12)
    axes[0].set_xlabel('Tratamiento', fontsize=12)
    axes[0].grid(True, linestyle='--', alpha=0.7)

    # Añadir medias con puntos
    tratamientos = df['Tratamiento'].unique()
    for i, tratamiento in enumerate(sorted(tratamientos)):
        media = df[df['Tratamiento'] == tratamiento]['Colesterol_Inicial'].mean()
        axes[0].scatter(i, media, marker='o', color='red', s=80, label='Media' if i == 0 else "")
        axes[0].text(i, media + 2, f'{media:.1f}', ha='center', va='bottom', fontweight='bold')

    # Boxplot para Colesterol Final
    sns.boxplot(x='Tratamiento', y='Colesterol_Final', data=df, ax=axes[1], palette=paleta)
    sns.stripplot(x='Tratamiento', y='Colesterol_Final', data=df, ax=axes[1],
                 color='black', alpha=0.5, jitter=True, size=4)

    axes[1].set_title('Colesterol Final por Tratamiento', fontsize=14)
    axes[1].set_ylabel('Colesterol Final', fontsize=12)
    axes[1].set_xlabel('Tratamiento', fontsize=12)
    axes[1].grid(True, linestyle='--', alpha=0.7)

    # Añadir medias con puntos
    for i, tratamiento in enumerate(sorted(tratamientos)):
        media = df[df['Tratamiento'] == tratamiento]['Colesterol_Final'].mean()
        axes[1].scatter(i, media, marker='o', color='red', s=80)
        axes[1].text(i, media + 2, f'{media:.1f}', ha='center', va='bottom', fontweight='bold')

    # Añadir una leyenda en el primer gráfico
    if not axes[0].get_legend():
        axes[0].legend(['Media'], loc='upper right')

    # Ajuste del layout
    plt.tight_layout()
    plt.savefig('boxplots_colesterol.png', dpi=300, bbox_inches='tight')
    plt.show()  # Mostrar el gráfico en Colab

    print("\nInterpretación de los boxplots:")

    # Análisis de los boxplots para cada tratamiento (colesterol final)
    for tratamiento in ['A', 'B', 'C']:
        grupo = df[df['Tratamiento'] == tratamiento]

        q1 = grupo['Colesterol_Final'].quantile(0.25)
        q3 = grupo['Colesterol_Final'].quantile(0.75)
        iqr = q3 - q1
        outliers = grupo[(grupo['Colesterol_Final'] < q1 - 1.5 * iqr) | (grupo['Colesterol_Final'] > q3 + 1.5 * iqr)]

        print(f"\nTratamiento {tratamiento} (Colesterol Final):")
        print(f"  Mediana: {grupo['Colesterol_Final'].median():.2f}")
        print(f"  Rango intercuartílico (IQR): {iqr:.2f}")
        print(f"  Número de valores atípicos (outliers): {len(outliers)}")
        if len(outliers) > 0:
            print(f"  Outliers: {outliers['Colesterol_Final'].values}")

# 6. Verificación de supuestos ANOVA
def verificar_supuestos_anova(df):
    """
    Verifica los supuestos para realizar un ANOVA:
    normalidad, homocedasticidad e independencia.
    """
    print("\n--- VERIFICACIÓN DE SUPUESTOS ANOVA ---")

    # 1. Normalidad - Ya analizada en la función anterior
    print("\n1. Normalidad:")
    print("  Ya evaluada en la sección de análisis de normalidad.")

    # 2. Homocedasticidad (homogeneidad de varianzas)
    print("\n2. Homocedasticidad (homogeneidad de varianzas):")

    # Test de Levene
    levene_inicial = stats.levene(
        df[df['Tratamiento'] == 'A']['Colesterol_Inicial'],
        df[df['Tratamiento'] == 'B']['Colesterol_Inicial'],
        df[df['Tratamiento'] == 'C']['Colesterol_Inicial']
    )

    levene_final = stats.levene(
        df[df['Tratamiento'] == 'A']['Colesterol_Final'],
        df[df['Tratamiento'] == 'B']['Colesterol_Final'],
        df[df['Tratamiento'] == 'C']['Colesterol_Final']
    )

    print(f"  Test de Levene para Colesterol Inicial: estadístico={levene_inicial.statistic:.4f}, p-valor={levene_inicial.pvalue:.4f}")
    if levene_inicial.pvalue > 0.05:
        print("    ✓ Las varianzas parecen ser homogéneas para Colesterol Inicial (p > 0.05)")
    else:
        print("    ✗ Las varianzas no parecen ser homogéneas para Colesterol Inicial (p ≤ 0.05)")

    print(f"  Test de Levene para Colesterol Final: estadístico={levene_final.statistic:.4f}, p-valor={levene_final.pvalue:.4f}")
    if levene_final.pvalue > 0.05:
        print("    ✓ Las varianzas parecen ser homogéneas para Colesterol Final (p > 0.05)")
    else:
        print("    ✗ Las varianzas no parecen ser homogéneas para Colesterol Final (p ≤ 0.05)")

    # 3. Independencia
    print("\n3. Independencia:")
    print("  La independencia de las observaciones es un supuesto que se verifica a través del diseño del estudio.")
    print("  En este caso, asumimos que los pacientes fueron asignados aleatoriamente a los tratamientos y")
    print("  que las mediciones entre pacientes son independientes.")

    # Visualización de residuos vs predichos para evaluar homocedasticidad
    modelo = ols('Colesterol_Final ~ C(Tratamiento)', data=df).fit()

    # Obtener residuos y valores ajustados
    df['residuos'] = modelo.resid
    df['ajustados'] = modelo.fittedvalues

    # Gráfico de residuos vs valores ajustados
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x='ajustados', y='residuos', hue='Tratamiento', data=df, alpha=0.7)
    plt.axhline(y=0, color='r', linestyle='-', alpha=0.3)
    plt.title('Residuos vs Valores Ajustados')
    plt.xlabel('Valores Ajustados')
    plt.ylabel('Residuos')
    plt.tight_layout()
    plt.savefig('residuos_vs_ajustados.png')
    plt.show()  # Añadido para mostrar el gráfico en Colab

    # Conclusión
    print("\nConclusión de verificación de supuestos:")
    supuestos_cumplidos = levene_final.pvalue > 0.05
    print(f"  {'✓' if supuestos_cumplidos else '✗'} Los supuestos para realizar un ANOVA {'parecen estar cumplidos' if supuestos_cumplidos else 'podrían no estar completamente cumplidos'}.")
    print("  Se recomienda proceder con el análisis, pero interpretar los resultados con cautela.")

# 7. Análisis de datos iniciales (ANOVA one-way)
def analisis_datos_iniciales(df):
    """
    Estudia las diferencias entre medias iniciales según variables categóricas.
    Utiliza ANOVA de una vía (one-way).
    """
    print("\n--- ANÁLISIS DE DATOS INICIALES (ANOVA ONE-WAY) ---")

    # ANOVA para colesterol inicial por tratamiento
    modelo_inicial = ols('Colesterol_Inicial ~ C(Tratamiento)', data=df).fit()
    tabla_anova_inicial = sm.stats.anova_lm(modelo_inicial)

    print("\nANOVA - Colesterol Inicial por Tratamiento:")
    print(tabla_anova_inicial)

    if tabla_anova_inicial['PR(>F)'][0] > 0.05:
        print("\n✓ No hay diferencias significativas en el colesterol inicial entre grupos de tratamiento.")
        print("  Esto sugiere que la aleatorización fue efectiva.")
    else:
        print("\n✗ Hay diferencias significativas en el colesterol inicial entre grupos de tratamiento.")
        print("  Esto podría indicar un sesgo en la asignación de tratamientos.")

    # T-test para colesterol inicial por sexo
    t_test_sexo = stats.ttest_ind(
        df[df['Sexo'] == 'Masculino']['Colesterol_Inicial'],
        df[df['Sexo'] == 'Femenino']['Colesterol_Inicial'],
        equal_var=True
    )

    print("\nT-test - Colesterol Inicial por Sexo:")
    print(f"Estadístico t: {t_test_sexo.statistic:.4f}")
    print(f"Valor p: {t_test_sexo.pvalue:.4f}")

    if t_test_sexo.pvalue > 0.05:
        print("\n✓ No hay diferencias significativas en el colesterol inicial entre hombres y mujeres.")
    else:
        print("\n✗ Hay diferencias significativas en el colesterol inicial entre hombres y mujeres.")

    # Correlación entre edad y colesterol inicial
    corr_edad_colesterol = stats.pearsonr(df['Edad'], df['Colesterol_Inicial'])

    print("\nCorrelación entre Edad y Colesterol Inicial:")
    print(f"Coeficiente de correlación: {corr_edad_colesterol.statistic:.4f}")
    print(f"Valor p: {corr_edad_colesterol.pvalue:.4f}")

    if corr_edad_colesterol.pvalue > 0.05:
        print("No hay correlación significativa entre la edad y el colesterol inicial.")
    else:
        if corr_edad_colesterol.statistic > 0:
            print(f"Hay una correlación positiva significativa entre la edad y el colesterol inicial.")
        else:
            print(f"Hay una correlación negativa significativa entre la edad y el colesterol inicial.")

    # Visualización de las medias iniciales por grupo
    plt.figure(figsize=(12, 6))

    # Medias por tratamiento
    plt.subplot(1, 2, 1)
    sns.barplot(x='Tratamiento', y='Colesterol_Inicial', data=df, ci=95)
    plt.title('Colesterol Inicial por Tratamiento')
    plt.ylabel('Colesterol Inicial (media ± IC 95%)')

    # Medias por sexo
    plt.subplot(1, 2, 2)
    sns.barplot(x='Sexo', y='Colesterol_Inicial', data=df, ci=95)
    plt.title('Colesterol Inicial por Sexo')
    plt.ylabel('Colesterol Inicial (media ± IC 95%)')

    plt.tight_layout()
    plt.savefig('medias_iniciales.png')
    plt.show()  # Añadido para mostrar el gráfico en Colab

    # Evaluación de posibles sesgos
    print("\nEvaluación de posibles sesgos en el diseño del estudio:")
    if tabla_anova_inicial['PR(>F)'][0] > 0.05 and t_test_sexo.pvalue > 0.05:
        print("  ✓ No se detectan sesgos evidentes en la asignación de tratamientos.")
        print("    La distribución del colesterol inicial es similar entre grupos de tratamiento y sexo.")
    else:
        print("  ✗ Se detectan posibles sesgos en el diseño del estudio:")
        if tabla_anova_inicial['PR(>F)'][0] <= 0.05:
            print("    - Diferencias en el colesterol inicial entre grupos de tratamiento.")
        if t_test_sexo.pvalue <= 0.05:
            print("    - Diferencias en el colesterol inicial entre hombres y mujeres.")

# 8. Análisis de ANOVA de dos factores (Two-factor ANOVA)
def analisis_anova_dos_factores(df):
    """
    Realiza un ANOVA de dos factores para evaluar los efectos
    del tratamiento y el sexo sobre el colesterol final.
    """
    print("\n--- ANÁLISIS DE ANOVA DE DOS FACTORES ---")

    # ANOVA de dos factores: Tratamiento y Sexo
    modelo = ols('Colesterol_Final ~ C(Tratamiento) + C(Sexo) + C(Tratamiento):C(Sexo)', data=df).fit()
    tabla_anova = sm.stats.anova_lm(modelo, typ=2)

    print("\nANOVA de dos factores - Colesterol Final:")
    print(tabla_anova)

    # Interpretación de los efectos principales
    print("\nInterpretación de los efectos principales:")

    # Efecto del tratamiento
    if tabla_anova.iloc[0, -1] <= 0.05:
        print(f"✓ El tratamiento tiene un efecto significativo sobre el colesterol final (p={tabla_anova.iloc[0, -1]:.4f}).")
    else:
        print(f"✗ El tratamiento no tiene un efecto significativo sobre el colesterol final (p={tabla_anova.iloc[0, -1]:.4f}).")

    # Efecto del sexo
    if tabla_anova.iloc[1, -1] <= 0.05:
        print(f"✓ El sexo tiene un efecto significativo sobre el colesterol final (p={tabla_anova.iloc[1, -1]:.4f}).")
    else:
        print(f"✗ El sexo no tiene un efecto significativo sobre el colesterol final (p={tabla_anova.iloc[1, -1]:.4f}).")

    # Interacción
    if tabla_anova.iloc[2, -1] <= 0.05:
        print(f"✓ Existe una interacción significativa entre tratamiento y sexo (p={tabla_anova.iloc[2, -1]:.4f}).")
        print("  Esto indica que el efecto del tratamiento varía según el sexo del paciente.")
    else:
        print(f"✗ No existe una interacción significativa entre tratamiento y sexo (p={tabla_anova.iloc[2, -1]:.4f}).")
        print("  Esto indica que el efecto del tratamiento es similar para ambos sexos.")

    # Creamos una figura con dos subplots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

    # Colores pastel personalizados
    colores_sexo = {"Masculino": "#A8D8EA", "Femenino": "#FCBAD3"}

    # 1. Gráfico de interacción (pointplot)
    sns.pointplot(x='Tratamiento', y='Colesterol_Final', hue='Sexo', data=df,
                 errorbar=('ci', 95), dodge=0.5, palette=colores_sexo, ax=ax1,
                 markers=["o", "s"], linestyles=["-", "--"], scale=1.2)

    ax1.set_title('Interacción entre Tratamiento y Sexo', fontsize=14)
    ax1.set_ylabel('Colesterol Final (media ± IC 95%)', fontsize=12)
    ax1.set_xlabel('Tratamiento', fontsize=12)
    ax1.legend(title='Sexo', title_fontsize=12, fontsize=10)
    ax1.grid(True, linestyle='--', alpha=0.7)

    # Añadir anotaciones con valores medios
    for sexo_idx, sexo in enumerate(["Masculino", "Femenino"]):
        for trat_idx, tratamiento in enumerate(["A", "B", "C"]):
            subgrupo = df[(df['Sexo'] == sexo) & (df['Tratamiento'] == tratamiento)]
            media = subgrupo['Colesterol_Final'].mean()
            # Ajustar posición según el dodge
            x_pos = trat_idx + (0.25 if sexo_idx == 0 else -0.25)
            ax1.text(x_pos, media + 2, f'{media:.1f}', ha='center', va='bottom',
                    fontsize=9, fontweight='bold', color='black')

    # 2. Gráfico de barras apiladas
    # Preparar datos para barras apiladas
    result = df.groupby(['Tratamiento', 'Sexo'])['Colesterol_Final'].mean().unstack()
    result.plot(kind='bar', stacked=False, ax=ax2, color=[colores_sexo["Masculino"], colores_sexo["Femenino"]])

    ax2.set_title('Colesterol Final por Tratamiento y Sexo', fontsize=14)
    ax2.set_ylabel('Colesterol Final (media)', fontsize=12)
    ax2.set_xlabel('Tratamiento', fontsize=12)
    ax2.legend(title='Sexo', fontsize=10)
    ax2.grid(True, linestyle='--', alpha=0.7, axis='y')

    # Añadir etiquetas con valores medios en cada barra
    for container in ax2.containers:
        ax2.bar_label(container, fmt='%.1f', fontsize=10, fontweight='bold')

    plt.tight_layout()
    plt.savefig('interaccion_tratamiento_sexo.png', dpi=300, bbox_inches='tight')
    plt.show()  # Mostrar el gráfico en Colab

# 9. Análisis de datos pareados
def analisis_datos_pareados(df):
    """
    Realiza un análisis de datos pareados para evaluar la eficacia de cada tratamiento.
    """
    print("\n--- ANÁLISIS DE DATOS PAREADOS ---")

    # Crear DataFrame para almacenar resultados
    resultados = []

    # T-test pareado para cada grupo de tratamiento
    for tratamiento in ['A', 'B', 'C']:
        grupo = df[df['Tratamiento'] == tratamiento]

        # T-test pareado
        t_test_pareado = stats.ttest_rel(
            grupo['Colesterol_Inicial'],
            grupo['Colesterol_Final']
        )

        # Calcular diferencia para evaluar el tamaño del efecto
        diferencia = grupo['Colesterol_Inicial'] - grupo['Colesterol_Final']
        mean_diff = diferencia.mean()
        sd_diff = diferencia.std()
        cohen_d = mean_diff / sd_diff

        # Almacenar resultados
        resultados.append({
            'Tratamiento': tratamiento,
            'Media_Inicial': grupo['Colesterol_Inicial'].mean(),
            'Media_Final': grupo['Colesterol_Final'].mean(),
            'Diferencia_Media': mean_diff,
            'Estadistico_t': t_test_pareado.statistic,
            'Valor_p': t_test_pareado.pvalue,
            'Tamaño_Efecto': cohen_d
        })

        print(f"\nTratamiento {tratamiento}:")
        print(f"  Colesterol Inicial (media ± DE): {grupo['Colesterol_Inicial'].mean():.2f} ± {grupo['Colesterol_Inicial'].std():.2f}")
        print(f"  Colesterol Final (media ± DE): {grupo['Colesterol_Final'].mean():.2f} ± {grupo['Colesterol_Final'].std():.2f}")
        print(f"  Disminución media: {mean_diff:.2f}")
        print(f"  T-test pareado: estadístico t={t_test_pareado.statistic:.4f}, p-valor={t_test_pareado.pvalue:.8f}")

        # Interpretación
        if t_test_pareado.pvalue <= 0.05:
            print(f"  ✓ El tratamiento {tratamiento} produjo una reducción estadísticamente significativa del colesterol (p ≤ 0.05).")
        else:
            print(f"  ✗ El tratamiento {tratamiento} no produjo una reducción estadísticamente significativa del colesterol (p > 0.05).")

        print(f"  Tamaño del efecto (d de Cohen): {cohen_d:.2f}")
        if abs(cohen_d) < 0.2:
            interpretacion = "muy pequeño"
        elif abs(cohen_d) < 0.5:
            interpretacion = "pequeño"
        elif abs(cohen_d) < 0.8:
            interpretacion = "mediano"
        else:
            interpretacion = "grande"
        print(f"  El tamaño del efecto es {interpretacion}.")

    # Crear DataFrame con resultados
    df_resultados = pd.DataFrame(resultados)

    # Visualización de resultados
    plt.figure(figsize=(15, 6))

    # Comparación visual de medias pre-post
    # Para cada tratamiento
    for i, tratamiento in enumerate(['A', 'B', 'C']):
        plt.subplot(1, 3, i+1)

        grupo = df[df['Tratamiento'] == tratamiento]

        # Crear un dataframe largo para seaborn
        data_long = pd.DataFrame({
            'Paciente': np.concatenate([grupo.index, grupo.index]),
            'Tiempo': ['Inicial'] * len(grupo) + ['Final'] * len(grupo),
            'Colesterol': np.concatenate([grupo['Colesterol_Inicial'], grupo['Colesterol_Final']])
        })

        # Graficar
        sns.boxplot(x='Tiempo', y='Colesterol', data=data_long)
        plt.title(f'Tratamiento {tratamiento}')

        # Añadir líneas conectando medias
        media_inicial = grupo['Colesterol_Inicial'].mean()
        media_final = grupo['Colesterol_Final'].mean()
        plt.plot([0, 1], [media_inicial, media_final], 'r-', linewidth=2)

        # Añadir etiquetas con medias
        plt.text(0, media_inicial + 3, f'{media_inicial:.1f}', ha='center')
        plt.text(1, media_final - 3, f'{media_final:.1f}', ha='center')

    plt.tight_layout()
    plt.savefig('cambios_pre_post.png')
    plt.show()  # Añadido para mostrar el gráfico en Colab

    # Tabla de resultados
    print("\nResumen de resultados de los tests pareados:")
    print(df_resultados[['Tratamiento', 'Diferencia_Media', 'Valor_p', 'Tamaño_Efecto']].to_string(index=False))

# 10. Análisis ANOVA para colesterol final (comparación entre tratamientos)
def analisis_anova_colesterol_final(df):
    """
    Aplica ANOVA de una vía para comparar el colesterol final entre tratamientos
    y determinar cuál es el más efectivo.
    """
    print("\n--- ANÁLISIS ANOVA PARA COLESTEROL FINAL ---")

    # ANOVA para colesterol final por tratamiento
    modelo = ols('Colesterol_Final ~ C(Tratamiento)', data=df).fit()
    tabla_anova = sm.stats.anova_lm(modelo)

    print("\nANOVA - Comparación de Colesterol Final por Tratamiento:")
    print(tabla_anova)

    # Definir colores pastel personalizados para cada tratamiento
    colores_tratamiento = {
        'A': '#A8D8EA',  # Azul pastel
        'B': '#FCBAD3',  # Rosa pastel
        'C': '#B5EAD7'   # Verde pastel
    }
    paleta = [colores_tratamiento[t] for t in sorted(df['Tratamiento'].unique())]

    if tabla_anova['PR(>F)'][0] <= 0.05:
        print("\n✓ Hay diferencias significativas en el colesterol final entre los distintos tratamientos.")
        print(f"  (F({tabla_anova['df'][0]},{tabla_anova['df'][1]})={tabla_anova['F'][0]:.2f}, p={tabla_anova['PR(>F)'][0]:.4f})")

        # Comparaciones múltiples post-hoc (Tukey HSD)
        tukey = pairwise_tukeyhsd(
            endog=df['Colesterol_Final'],
            groups=df['Tratamiento'],
            alpha=0.05
        )

        print("\nComparaciones múltiples (Tukey HSD):")
        print(tukey)

        # Identificar el tratamiento más eficaz (menor colesterol final)
        medias_por_tratamiento = df.groupby('Tratamiento')['Colesterol_Final'].mean()
        mejor_tratamiento = medias_por_tratamiento.idxmin()

        print(f"\nEl tratamiento más eficaz es el {mejor_tratamiento} con un colesterol final medio de {medias_por_tratamiento[mejor_tratamiento]:.2f}.")

        # Comparaciones específicas
        # Extraer los resultados de Tukey en un formato más manejable
        tukey_data = pd.DataFrame(data={
            'group1': [x[0] for x in tukey._results_table.data[1:]],
            'group2': [x[1] for x in tukey._results_table.data[1:]],
            'meandiff': [x[2] for x in tukey._results_table.data[1:]],
            'p-value': [x[3] for x in tukey._results_table.data[1:]],
            'lower': [x[4] for x in tukey._results_table.data[1:]],
            'upper': [x[5] for x in tukey._results_table.data[1:]],
            'reject': [x[6] for x in tukey._results_table.data[1:]]
        })

        # Imprimir las comparaciones
        print("\nResultados detallados de las comparaciones:")
        for _, row in tukey_data.iterrows():
            if row['reject']:
                print(f"  • Hay diferencias significativas entre los tratamientos {row['group1']} y {row['group2']} (p={row['p-value']:.4f}).")
                print(f"    La diferencia media es de {abs(row['meandiff']):.2f} unidades.")
            else:
                print(f"  • No hay diferencias significativas entre los tratamientos {row['group1']} y {row['group2']} (p={row['p-value']:.4f}).")

    else:
        print("\n✗ No hay diferencias significativas en el colesterol final entre los distintos tratamientos.")
        print(f"  (F({tabla_anova['df'][0]},{tabla_anova['df'][1]})={tabla_anova['F'][0]:.2f}, p={tabla_anova['PR(>F)'][0]:.4f})")

    # Crear una figura de 2x2 para visualizaciones más completas
    fig, axes = plt.subplots(2, 2, figsize=(18, 14))

    # 1. Gráfico de barras con intervalos de confianza (arriba izquierda)
    sns.barplot(x='Tratamiento', y='Colesterol_Final', data=df, ci=95, palette=paleta, ax=axes[0, 0])
    axes[0, 0].set_title('Colesterol Final por Tratamiento', fontsize=14)
    axes[0, 0].set_ylabel('Colesterol Final (media ± IC 95%)', fontsize=12)
    axes[0, 0].set_xlabel('Tratamiento', fontsize=12)
    axes[0, 0].grid(True, linestyle='--', alpha=0.7, axis='y')

    # Añadir etiquetas con valores medios
    for i, tratamiento in enumerate(sorted(df['Tratamiento'].unique())):
        media = df[df['Tratamiento'] == tratamiento]['Colesterol_Final'].mean()
        axes[0, 0].text(i, media - 8, f'{media:.2f}', ha='center', va='top',
                        fontsize=12, fontweight='bold', color='black')

    # 2. Gráfico de dispersión con medias (arriba derecha)
    sns.stripplot(x='Tratamiento', y='Colesterol_Final', data=df, jitter=True,
                 alpha=0.5, palette=paleta, ax=axes[0, 1])
    sns.pointplot(x='Tratamiento', y='Colesterol_Final', data=df, join=False,
                 color='red', scale=1.5, ax=axes[0, 1])
    axes[0, 1].set_title('Distribución de Colesterol Final por Tratamiento', fontsize=14)
    axes[0, 1].set_ylabel('Colesterol Final', fontsize=12)
    axes[0, 1].set_xlabel('Tratamiento', fontsize=12)
    axes[0, 1].grid(True, linestyle='--', alpha=0.7, axis='y')

    # 3. Violinplot (abajo izquierda)
    sns.violinplot(x='Tratamiento', y='Colesterol_Final', data=df, palette=paleta,
                  inner='quartile', ax=axes[1, 0])
    axes[1, 0].set_title('Distribución de Colesterol Final (Violin Plot)', fontsize=14)
    axes[1, 0].set_ylabel('Colesterol Final', fontsize=12)
    axes[1, 0].set_xlabel('Tratamiento', fontsize=12)
    axes[1, 0].grid(True, linestyle='--', alpha=0.7, axis='y')

    # Añadir medias al violinplot
    for i, tratamiento in enumerate(sorted(df['Tratamiento'].unique())):
        media = df[df['Tratamiento'] == tratamiento]['Colesterol_Final'].mean()
        axes[1, 0].scatter(i, media, color='red', s=80, zorder=3)
        axes[1, 0].text(i, media + 2, f'Media: {media:.2f}', ha='center', va='bottom',
                        fontsize=10, fontweight='bold')

    # 4. Visualización de las comparaciones de Tukey (abajo derecha)
    if tabla_anova['PR(>F)'][0] <= 0.05:
        # Convertir los resultados de Tukey en un gráfico
        comparaciones = []
        for _, row in tukey_data.iterrows():
            comparaciones.append({
                'Comparación': f"{row['group1']} vs {row['group2']}",
                'Diferencia': row['meandiff'],
                'p-valor': row['p-value'],
                'Significativo': 'Sí' if row['reject'] else 'No',
                'lower': row['lower'],
                'upper': row['upper']
            })

        df_comp = pd.DataFrame(comparaciones)

        # Crear un gráfico de forest plot para las comparaciones
        y_pos = range(len(df_comp))

        # Graficar las diferencias con intervalos de confianza - usando un solo color
        axes[1, 1].errorbar(
            x=df_comp['Diferencia'],
            y=y_pos,
            xerr=np.vstack([
                df_comp['Diferencia'] - df_comp['lower'],
                df_comp['upper'] - df_comp['Diferencia']
            ]),
            fmt='o',
            capsize=5,
            capthick=2,
            markersize=10,
            color='royalblue'  # Color único para todas las barras de error
        )

        # Añadir una línea vertical en cero
        axes[1, 1].axvline(x=0, color='gray', linestyle='--', alpha=0.7)

        # Configurar etiquetas y título
        axes[1, 1].set_yticks(y_pos)
        axes[1, 1].set_yticklabels(df_comp['Comparación'])
        axes[1, 1].set_xlabel('Diferencia en Colesterol Final', fontsize=12)
        axes[1, 1].set_title('Comparaciones Post-hoc (Tukey HSD)', fontsize=14)
        axes[1, 1].grid(True, linestyle='--', alpha=0.7, axis='x')

        # Añadir p-valores y significancia
        for i, row in df_comp.iterrows():
            color = 'red' if row['Significativo'] == 'Sí' else 'black'
            axes[1, 1].text(
                row['Diferencia'] + (8 if row['Diferencia'] > 0 else -8),
                i,
                f"p={row['p-valor']:.4f} ({'*' if row['Significativo'] == 'Sí' else 'ns'})",
                va='center',
                color=color,
                fontweight='bold' if row['Significativo'] == 'Sí' else 'normal'
            )
    else:
        # Si no hay diferencias significativas, mostrar un mensaje
        axes[1, 1].text(0.5, 0.5, "No hay diferencias significativas\nentre los tratamientos",
                       ha='center', va='center', fontsize=14, transform=axes[1, 1].transAxes)
        axes[1, 1].set_title('Comparaciones Post-hoc (Tukey HSD)', fontsize=14)
        axes[1, 1].axis('off')

    plt.tight_layout()
    plt.savefig('comparacion_colesterol_final.png', dpi=300, bbox_inches='tight')
    plt.show()  # Mostrar el gráfico en Colab

# Función principal
def main():
    """
    Función principal que ejecuta todos los análisis.
    """
    # Cargar datos
    df = cargar_datos()

    # Realizar análisis
    analisis_descriptivo(df)
    analisis_univariante(df)
    analisis_normalidad(df)
    analisis_boxplot(df)
    verificar_supuestos_anova(df)
    analisis_datos_iniciales(df)
    analisis_anova_dos_factores(df)
    analisis_datos_pareados(df)
    analisis_anova_colesterol_final(df)

    print("\n--- RESUMEN Y CONCLUSIONES ---")
    print("\nEl análisis realizado permite extraer las siguientes conclusiones:")

    # Evaluar si hay diferencias entre grupos iniciales
    print("\n1. Respecto a los datos iniciales:")
    modelo_inicial = ols('Colesterol_Inicial ~ C(Tratamiento)', data=df).fit()
    tabla_anova_inicial = sm.stats.anova_lm(modelo_inicial)
    if tabla_anova_inicial['PR(>F)'][0] > 0.05:
        print("  ✓ No se detectaron diferencias significativas en el colesterol inicial entre los grupos de tratamiento,")
        print("    lo que sugiere una aleatorización adecuada.")
    else:
        print("  ✗ Se detectaron diferencias significativas en el colesterol inicial entre los grupos de tratamiento,")
        print("    lo que podría indicar problemas en la aleatorización o sesgos de selección.")

    # Evaluar eficacia de cada tratamiento
    print("\n2. Respecto a la eficacia de los tratamientos:")
    for tratamiento in ['A', 'B', 'C']:
        grupo = df[df['Tratamiento'] == tratamiento]
        t_test_pareado = stats.ttest_rel(grupo['Colesterol_Inicial'], grupo['Colesterol_Final'])

        if t_test_pareado.pvalue <= 0.05:
            print(f"  ✓ El tratamiento {tratamiento} es eficaz para reducir el colesterol (p={t_test_pareado.pvalue:.6f}).")
        else:
            print(f"  ✗ El tratamiento {tratamiento} no mostró eficacia significativa (p={t_test_pareado.pvalue:.6f}).")

    # Evaluar diferencias entre tratamientos
    modelo = ols('Colesterol_Final ~ C(Tratamiento)', data=df).fit()
    tabla_anova = sm.stats.anova_lm(modelo)

    print("\n3. Respecto a la comparación entre tratamientos:")
    if tabla_anova['PR(>F)'][0] <= 0.05:
        # Identificar el tratamiento más eficaz
        medias_por_tratamiento = df.groupby('Tratamiento')['Colesterol_Final'].mean()
        mejor_tratamiento = medias_por_tratamiento.idxmin()

        print(f"  ✓ Existen diferencias significativas entre los tratamientos (p={tabla_anova['PR(>F)'][0]:.6f}).")
        print(f"  El tratamiento más eficaz es el {mejor_tratamiento} con un colesterol final medio de {medias_por_tratamiento[mejor_tratamiento]:.2f}.")
    else:
        print(f"  ✗ No existen diferencias significativas entre los tratamientos (p={tabla_anova['PR(>F)'][0]:.6f}).")

# Ejemplo de uso
if __name__ == "__main__":
    # En Google Colab, no necesitamos pasar la ruta del archivo
    # ya que el usuario lo subirá interactivamente
    main()
# Out:
# Por favor, sube el archivo Excel con los datos del estudio.
# Haz clic en el botón 'Elegir archivos' que aparecerá.
#      <input type="file" id="files-5e1ea69d-fc6a-459c-acab-92c865b50d66" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e1ea69d-fc6a-459c-acab-92c865b50d66">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
# Frecuencias absolutas
frecuencia_abs = df['Sexo'].value_counts()

# Frecuencias relativas (en %)
frecuencia_rel = df['Sexo'].value_counts(normalize=True) * 100

# Mostrar resultados
sexo_summary = pd.DataFrame({
    'Frecuencia absoluta': frecuencia_abs,
    'Frecuencia relativa (%)': frecuencia_rel.round(2)
})

display(sexo_summary)
# Out:
#            Frecuencia absoluta  Frecuencia relativa (%)
# Sexo
# Masculino                   76                    50.67
# Femenino                    74                    49.33

# %%
def analisis_normalidad(df):
    """
    Evalúa la normalidad de las variables en los tres grupos de tratamiento
    mediante pruebas estadísticas (Shapiro y Kolmogorov-Smirnov) y gráficos Q-Q.
    """
    print("\n--- ANÁLISIS DE NORMALIDAD ---")

    variables = ['Colesterol_Inicial', 'Colesterol_Final']

    for var in variables:
        print(f"\nPruebas de normalidad para {var} por grupo de tratamiento:")

        for nombre_tratamiento, grupo in df.groupby('Tratamiento'):
            # Shapiro-Wilk
            shapiro_test = stats.shapiro(grupo[var])
            shapiro_p = shapiro_test.pvalue
            print(f"  Shapiro-Wilk - Tratamiento {nombre_tratamiento}: p = {shapiro_p:.4f}")

            # Kolmogorov-Smirnov ajustado a la media y std del grupo
            media = grupo[var].mean()
            std = grupo[var].std()
            ks_test = stats.kstest(grupo[var], 'norm', args=(media, std))
            print(f"  Kolmogorov-Smirnov - Tratamiento {nombre_tratamiento}: p = {ks_test.pvalue:.4f}")

            # Gráfico Q-Q + histograma
            fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

            # Q-Q Plot
            sm.qqplot(grupo[var], line='s', ax=ax1)
            ax1.set_title(f'Gráfico Q-Q - Tratamiento {nombre_tratamiento}')
            ax1.grid(True, linestyle='--', alpha=0.7)

            # Histograma con curva normal
            color = {'A': '#A8D8EA', 'B': '#FCBAD3', 'C': '#B5EAD7'}[nombre_tratamiento]
            sns.histplot(grupo[var], kde=True, ax=ax2, color=color)
            x = np.linspace(grupo[var].min(), grupo[var].max(), 100)
            y = stats.norm.pdf(x, media, std)
            y = y * len(grupo[var]) * (x[1] - x[0])
            ax2.plot(x, y, 'r-', linewidth=2)
            ax2.set_title(f'Histograma - Tratamiento {nombre_tratamiento}')
            ax2.grid(True, linestyle='--', alpha=0.7)

            plt.tight_layout()
            plt.show()

        # Normalidad general
        print(f"\nNormalidad general para {var} (todos los grupos):")
        shapiro_all = stats.shapiro(df[var])
        ks_all = stats.kstest(df[var], 'norm', args=(df[var].mean(), df[var].std()))
        print(f"  Shapiro-Wilk global: p = {shapiro_all.pvalue:.4f}")
        print(f"  Kolmogorov-Smirnov global: p = {ks_all.pvalue:.4f}")

        plt.figure(figsize=(10, 6))
        sm.qqplot(df[var], line='s')
        plt.title(f'Q-Q Global - {var}')
        plt.grid(True, linestyle='--', alpha=0.7)
        plt.tight_layout()
        plt.show()
